# %% [markdown]
# # Investigation Thesis
# # Introduction to Investigation
# The path telling for the teacher to make a investigation path.
#
# ## Tips to improvement and know the state of time and work
# 1. Previous work of thesis is the advanced work (Need to sign ).
# - Science
# - Springer
# - IEEE
# - Scopus
#
# 2. The structure of some thesis:
# - Previous Work
# - Understand and description of the problem
# - Problem formulation
# - Objectives formulation
# - Variables
#
# 3. The environment help forward
# - 7 courses.
# - The tools like engine language transformes.
# - IA module to understand the sign peruvian language.
#
# ## Structure of the Investigation
#
# 1. **Problem Formulation:**
# - Identification of the problem.
# - Definition of the problem specific and General.
# - Objectives, hiphotesis, variables operation.
#
# 2. **Theoric and methodology:**
# - State of Arts.
# - Strategy of Theoric and the citation operation.
# - Design and Point View of the methodology.
#
# 3. **Work development:**
# - Make the goals like the first.
#
# ## Practice the tips
#
# 1. Prompt and add the desireus aproximativaly with the title.
#
# 2. Citations of other Thesis and joint and form the problematic.

# %% [markdown]
# # Analize the right topic to investigation
#
# **Prompt to found Bibliography**
# ```
# In the context of the problem of deaf adaptation to communicate their ideas in public space like hospital were need to told their hurts and the wall between the translator of signs Peruvian language available in this places is common, prepare a comprehensive technical report on the latest advances in this area. The development of Robot static assistant with CV to translate in real time the signs Peruvian language and the integration with another types of communication like the keyboard.
# The report should include only articles published in
# high-impact scientific journals from recognized
# publishers such as Elsevier, IEEE, and Springer-Nature.
# Additionally, identify and analyze three significant gaps in
# current knowledge that could become concrete
# opportunities for research projects.
# Ensure that the content is presented with academic rigor,
# including up-to-date and well-structured bibliographic
# references.
# ```
# 1. Generate in the Screen an Avatar in 3D translate visual the text
# 2. Use of the Glasses to help disabilities
# 3. If the product make their work with BBB (Bueno, Bonito, Barato) then this product have hight technology than other.
# **Variables:** Independent (Hidrogen) --> Dependent (Contaminantes Dust)
#
# General Objectives: Verbs + VD + VI
# Born about the General: Make more specifics Tasks
# The specific Objectives: Have 1 or 2 of the variables.
# Operational Matrix of this 2 variables

# %% [markdown]
# # Generalidades
#
# ## Antecedentes de la Investigación
#
# 1. Works with techniques to train the AI and make testing in the alphabets and numbers
# 2. Creation of 3D avatar how make a translation of text in signs avatar gesture sequency
# 3. The gloves development to show the translation of the position of hands and the translation in real time to children
# 4. In chile described problems born in the interaction of the deaf people with the doctors
#
# ## Identificación y Descripción del Problem de Estudio
#
# Right moment something happened with the theme and the thesis, the problematic is see with the perspective of the solution. In this case the solution we want make with computer vision then see the problematic like a part of this solution and defend it with all the pre thinking idea, of make with this, I think exist better solution to make a improve in the quality of the tools in the comunication field, how the deaf people can use to break the wall of understanding. Know in this moment. I felt lost to keep giving my effort to the project with this perspective. In this moment we need to understand what is the problem with numbers also the this need to understand what happened in the reality, what is see for the people suffer some type of unondurstend.
#
# ```
# # Prompt para abordar la incapacidad del habla como problemática
# Quiero que me definas la problemática que hay con las personas sin la capacidad de usar el habla como medio de comunicación y su entendimiento con personas que debido a esta incapacidad encuentran dificultades para su comprensión en la vida cotidiana. Además agrega qué soluciones se han planteado y desarrollado, elabora un
# informe técnico exhaustivo sobre los avances más recientes.
# El informe debe incluir únicamente artículos publicados en
# revistas científicas de alto impacto pertenecientes a editoras
# reconocidas como Elsevier, IEEE y Springer-Nature.
# Además, identifica y analiza tres brechas significativas en el
# conocimiento actual que puedan convertirse en oportunidades
# concretas para proyectos de investigación.
# Asegúrate de presentar el contenido con rigor académico,
# incluyendo referencias bibliográficas actualizadas y bien
# estructuradas.```
