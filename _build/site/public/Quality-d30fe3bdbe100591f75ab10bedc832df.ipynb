# %% [markdown]
# # Quality Process
#
# # The Search of Value
# We found and search the quality of the things search ideas and the dream, to this need the pruction of the things and the get some services.
#
# 1. End Goal: this is the desire the dream want achievement
# We can have the best of the dream and believe in search us and see us in 10 years seing how what and for what
# 2. The form: How get the things in this world a lot of things wanted doen´t depend about us this for example is reflexed in the knowledge to recovery this information who have is the doctor, every of us can have something special the left can want of us and this is the most valueble and need to share
# How get the things is really matter.
#
# ## The most matter components of the Quality
# 1. Thecnologia:
# 2. Food:
# 3. Transport:
# 4. Education:
# 5. Healthy:
# 6. Entertainment:
#
# :::{note}
# the terms of quality is if the thing make the function well,
# :::
#
# ## The circle of Quality
#
# 1. Planification: Actions to do
# 2. Doing: Do this
# 3. Verification and Control: Male solution or doesn't
# 4. Execution
#
# ## Testing if Provide a quality Work
#
# 1. Do you arrive in the time clock?
# 2. If you have to lie to dodge a lost make real lie?
# 3. What about of proactivity?
# 4. Make more than the provide to you?
#
#
# :::{note}
# The view-perspective is the most matter component and choice we can control the positive mind, and this is because is related with virtues and we can virtues to achieve our dreams
# :::
#
# ## Value of the quality huaman
#
# 1. The virtuos to achieve the dream meaning a lot of the most hardness and elevate with the practice values more happy. **Company and human need:
# - Ser: The value of the virtuos
# - hacer: Thing can control to make virtuos and dream
# - tener: This attraction of the virtuos get their nature, the
# - Be happy dream: achieve and live the most amazing history we want.
# :::{note}
# Dont make me remember because I return to this place. Comedy
# :::
#
# :::{note}
# The ethic is the expression of how we see and try to be our dream and act in this moment making and letting the virtuos act of this momment to make the most easy thing
# :::
#
# ## The true of the life
# **Always we can life with virtues in the all the time of this life**
#
# Why we work and offer the quality: to improve to this action and think to make virtuos thing my actions virtuos make a quality product to offer because I have something virtues can share to the world.
#
# :::{note}
# the virtuos action born and generate the virtuos
# :::
#
# ## The leadership
# the boos: ask and say for results, say all the achievement is of him and all the wrong is of the worker.
#
# the leadership: Get and help the worker, and make capacitation. How to make the thing, the leadership go in the front of the fight.
#
# ## All the ideas are allowed used the ideas of all
# Thecniques used:
# - 30% made the planification
# - and the left try to make understand with the time
# - if pass time and if some parts doesn't work then change it
# > all for one, one for all
# > Divide the process and inspection every input of each part and make shure all the parts are entry with good quality to have the good ouput quality

# %% [markdown]
# # 3 _ The focus in client, needed and Strategy
#
# Strategies to make the solution and to show and tell how this solution can be used for the client, we have something make good for you.
#
# ## Undestand what are the problem of the client and show the answer
# 1. Client value
# 2. Expirience
# 3. Relation with the client
# 5. Quality Gestion
# 6. Comunication standart channel
# 9. Continuos Improvment: Always exist a wave to make better and express the
# 10. Client trusted and confiability with the reward.
# The spreed of the positive and the relationshiop in the time
#
# ```
# Prompt to create a Flow diagram
# make a diagram of flowdiagram to myst engine of this quality + satisfaction + pass client expectation  this create a relation positive and persistence in the time
# ```
# ```mermaid
# flowchart TD
#     A[Identify Client Needs] --> B[Deliver Quality Solution]
#     A --> C[Ensure Client Satisfaction]
#     A --> D[Exceed Client Expectations]
#     B --> E[Build Trust & Reliability, Foster Positive Relationship, Persistence Over Time]
#     C --> E
#     D --> E
#     E --> H[Continuous Improvement]
#     H --> A
# ```
#
# **Prompt to make the PMBOK**
#
# ```
# maek a flowchart for diagram in myst to explain the phases of PMBOOK with the explanation text
# ```
#
# ## PMBOK Phases Flowchart
#
# The PMBOK (Project Management Body of Knowledge) defines five key phases in project management: Initiating, Planning, Executing, Monitoring & Controlling, and Closing. Each phase plays a critical role in ensuring project success.
#
# ```mermaid
# flowchart TD
#     A[Initiating<br>Define project goals, stakeholders, and scope] --> B[Planning<br>Develop roadmap, schedule, resources, and risk management]
#     B --> C[Executing<br>Carry out project plan, manage teams, and deliverables]
#     C --> D[Monitoring & Controlling<br>Track progress, manage changes, ensure quality]
#     D --> E[Closing<br>Finalize deliverables, release resources, document lessons learned]
# ```
#
# - **Initiating:** Establishes the foundation and purpose of the project.
# - **Planning:** Outlines how objectives will be achieved, including timelines and resources.
# - **Executing:** Focuses on completing the work defined in the plan.
# - **Monitoring & Controlling:** Ensures the project stays on track and adapts to changes.
# - **Closing:** Wraps up the project, ensuring all goals are met and documenting outcomes.
#
# ```mermaid
# flowchart TD
#     A[Plannification<br> Define the problem, goal, the acction in the time an the resources will use.] --> B[Doing<br>Make the actions in the plan.]
#     B --> C[Verification<br> Make the testing of the actions, if the goals was realizated.]
#     C --> D[Action<br> if was achieved then documentation and the closer acttion, if not began again the process.]
#     D --> A
# ```
#
#
# **Prompt to create the improvement steps**
#
# ```
# make a new flowchart myst with this 5 parts of the improvement: Problem Identification Planification Pilot Prototyping Verification Escalation
# ```
#
# ```mermaid
# flowchart TD
#     A[Problem Identification<br>Recognize and define the issue to be improved] --> B[Planification<br>Develop a strategy and action plan]
#     B --> C[Pilot Prototyping<br>Implement a small-scale test or prototype]
#     C --> D[Verification<br>Evaluate results and validate effectiveness]
#     D --> E[Escalation<br>Expand and standardize successful improvements]
# ```
