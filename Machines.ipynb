# %% [markdown]
# # Automatic Machines
#
# # Introduction to Automatic machine
#
# 1. The most value in the path of learning is the understand the desires to make it reality.
# 2. The value of the time in the path choice, and the perfection of the practices.
# 3. The understand of the reality of the force law.
#
# 1.- Advanced of the project APA IEEE
# 2.- Monografía 2, all the left project
# If the remaining time is few, then the monography 1 can be skiped taking only count the exposition PC. the exposition monography 2
#
# ## Division od the final Project
#
# 1. Mechanical Design: Resistance
# 2. Control: Detection, Tracking
# 3. HMI: SCREEN developer operation ()
# 4. Sensores: Encoders, Finales de carrera
# 5. Actuadores: MOTOR DC
# 6. Computer Vision: Identification of the main object (Gesture)
# 7. Monitoring: CONDITION OF THE SYSTEM (State of the Batery)
# 8. Embedded:
#
# ## The procces of design
#
# The problematic to resolve:
# 1. Assitance to automatic comunication between knowledge and non-knowledge speakers of sign language.
# 2. The needed is dependent of the context, reality have the reasoning used in this choice.
# 3. The learning the Sign Language now have.
#
# ## Path of Steps in the construction of the project
#
# 1. Exist the problematic with the client
# 2. Search the resources: How to Know, Convert to Machine, Finance Tools,
# 3. Design the product and how solve, what is the solution of this problem
# - **Arquitecture:** Dream the product the thinking procces
# - **Civil Enginnering:** Details specific aspect of the Product
# - **Construction follow of the manual planes:** Complete description the 0A planes
# 4. The legal declaration of the details of the product.
#
# Design Have 2 focus - Selection -

# %% [markdown]
# # Definition of the Problem
# This make the fundamental what I am need, what are the specific problem.
#
# FUNDAMENTAL PROBLEM:
# -
#
#
# 1. Found the need to translate for example 1 word for 0.3 seconds to make real time transduction
# 2. Need in 4 months
# 3. Economic Limitation to investment 20000
# 4. Grade of precission of >= 90 %
# 5. Types of the skins make detection, in perú have the most types of the color, all the types of color.
# 6. The material of the robot, resistance to the torsion of the camera. With charge 1 KG with maxim
# 7. HMI to change the main parameters, VELOCITY, ,
# 8. Velocity of the robot to interaction human cobot.
# 9. Use detection AI to detect conversation with 200 common words.
# .
#
# # Search of existent solution
# ## Search how someone solve this problem.
# *BIBLIOGRAPHY*
# > I am mechatronic, need to review the information, study to understand. To find the solution Implementation and tell the difference.
# - Search the solution of th
# ## Ideas Rain
#
# 1. Make a team origin storm to find and arme the structure
# 2. Optimization of the idea, making a optimization with the previos solution found it
#
#
# # Solution Implementation
#
# 1. Hire a arquitect to make the guide, the caulculation is the main topic to build it.
# 2. Cálculation of the proccess.
# 3. Define what are the right component to use.
#
# #
#
# #
