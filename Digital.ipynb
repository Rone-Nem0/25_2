# %% [markdown]
# # Digital Control
# # Introduction to Concepts in Digital Control
#
# ## Explanation of Hold
# in the aplication of the matlab is the same of ZOH (Zero Order Hold)
# the retation the challenge of this is understand the discretization of the every signal of every process
#
# ## The understanding of transferation of command and reading in control digital a plant
#
# Know the computers have requirements and the damage can be in them, with a lot of conditions. Is for this the commander is aisled of the Plant process knowing this process can be worked in dangerous extremous envrionment conditions.
# ![Interface](Digital/Block-Diagram-of-DCS-System-for-Manufacturing-Plant.png)
# ## Sofware principles with Labview
#
# Read the signal with ADC and write all this is knowing the frecuency and this is depended of Nyquist Principle
# Port ADC - port DAQ
#
# ZOH meaning convert f* to f' = u(t) - u(t-T)
# ![Band_ZOH](Digital/ZOH.png)
#
# this make the reteiton of the value for a windows a band to express the value continuosly.
#
# ## Time Tk
# all the computer have the clock to make continuosly operations in digital control the most relevant data is taked in this constant moments.
#
# t_k = KT
# the T is matter thing because of this time depend all the understand and apreciate the diferences.

# %% [markdown]
# # Explanation of the first Lab Data Adquisition
#
#
# this is the focus for the topic to get the laboratory, think in Labview to make a ghraphical interface
# - Potentiometer: to change the time sample adquisition and the changed variables
# - DAQ: is a microelectronic how allow the adquisition this is the interface and can found replacement like encoder.
# - In this case exist Led and buzzer to make acttions can be replaced for a Motor DC controloing a Motor DC with an interface like a driver
# - Is needed use an graphical Interface Like Labview to show the data READING
#
# ## Array Labview
# CREATE THE FIRST PROGRAM: file - ctr + t ->
# The structure of show the data of Labview
# FRONT PANEL | BLOCK DIAGRAM
#  ![DAQ_interface](Digital/DAQ.png)
#
#  ## Type of data
#  Numeric Control is input (Sensor, Potentiometer)
#  Numeric Indicator is output (Buzzer, Motor DC)
#
#  Representation of data in colors
#  Orange (DBL), Blue(Int), verde ( Boulean), Magenta( String)
# ![Color_Data](Digital/Cable_Data_Color.jpeg)
#
# the teacher is controling the cable colors and the type of data COONTROL, INDICATOR, INDEX ( position of the data in the array)
#
# ## Goals of the first laboratory
# - Understand the relevant of have an aplication like the builder of interface allow to show and see friendly like dash board the data measured.
# - Labview is a software allow to work with the data input and the get the response.
# - Labview use the USB-6000 to take the data, this is their interface
#
# 1. the exercise data to read with the dack
# 2. Comunication of data with the board.
#
# :::{note}
# - The tool to be used are the PymoDAQ
# - Another explained are the Node - Red
# :::

# %% [markdown]
# # Learn using the Silabus and automatic teacher
#
# **Prompt make it for me to use the silabus and the copilot**
#
# ```
# analize this pdf and tell me problems and prototype answer with python, like you are an expert in Digital control and mit teacher, in every unity of learning give me 3 challengue to development involve all the points of touch with this sylabus
# ```
# ```
# also give me 3 challenge using this tools python microcontrolers like arduino esp32 and simulatiors like wokwi to make the completations of this challengue and explain the pros and the main focus skills to development.
# ```
# ```
# how can make adquisition of data with esp32 in wokwi to make a simulation of IoT, explain me what is the regresion technique and for what is used is for make prediction?
# ```
#
# ## The relevant of use the digital control
# This is because development for example an INA with OPAN working in analog with continuos data is hardness to modify, to this usually is make it the change of resistance and condensators.
#
#
# :::{note}
# Using digital control allows for flexible and rapid modifications to system behavior through software, rather than physically altering hardware components. This enables easier prototyping, testing, and deployment of control strategies, especially when integrating with microcontrollers and IoT platforms.
# :::
#
# ## Reconstruction of the discrete signal
# The flow of operations
#
# ```{mermaid}
# flowchart LR
#     A["f(t): Continuous Signal"] --> B[Sampling]
#     B --> C["f*(t): Discrete Signal"]
#     C --> D[Hold Operation]
#     D --> E["fs(t): Reconstructed Signal"]
# ```
# **Prompt**
#
# ```
# give me a list of steps to make adquisition of data with esp32 in VSC ubuntu 24.04 with a potentiometer
# ```
#
# **Prompt**
#
# ```
# como un experto en control digital, explícame como el LABVIEW puede ser integrado con el esp32 y porqué la combinación de DAQ 6001 y el LABVIEW es tan importante y para qué aplicaciones su combinación supera a sus competidores
# ```
#
# # Testing the I/O pinout with the NI MAX
#
# This provide the finish I/O interface to work with the pin in digital and analog, only need connect the circuit with the entry of the DAQ 6001 and
#
# # Understand the deepness of the DAQ
#
# ## Measurement I/O
# 1. Create the measurement/ channel box
# 2. Create constant in the phisical channel in this part is from analog chanel
# 3. Set the :
# - maximum and the
# - minimum value to plot the entry analog input and
# - create the mode of the terminal input, the configuration.
# - **With this configure the entry the take of the analog signal to make procesing**
# 4. Define the task of the receive the input values with **Start Task Box**
#
# 5. Insert the structure of the loop while were we can make the catc it of the value entry to make the plot after
#
# 6. Insert the read once the data entry in the microcontroler
#
# 7. Ask to AI what is the box of the while
#
# **prompt**
# ```
# please en labview how is named the block how have how input , time end, sampling frecuency, variable i of the while loop, also IT (for example I32) and T (for example DBL) a button red of stop and output were add with a multiplication with 1000 get the clock symbol
# ```
# ```
# para este proyecto dame la guía de pasos para configurar el box de while loop like if you are the teacher of control digital teach the labview interface name of block and understand for what is used each block and the sequence.
# ```
#
# 7. Skip the time clock and go with the save the files "write to measurement file" this is for have a file with the values like have excel
#
# 8. The logic of have a wait to take data is needed define a time a value of time, to this the entry and value define will be in Ts sampling time x 1000 because "wait" use the miliseconds. To express the value of time is needed multiply the Ts x i this define what part of the bucle is running.
#
# 9. Put a conditional to define when the time running the IT > time max of running.
# ![alt text](Digital/DAQ_potentiometer.jpeg)
